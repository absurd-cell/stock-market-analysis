# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
data = pd.read_csv("DATA.csv")

print("🔹 FIRST 5 ROWS")
print(data.head())

print("\n🔹 LAST 5 ROWS")
print(data.tail())
# Out:
# 🔹 FIRST 5 ROWS
#         DATE SERIES      OPEN      HIGH       LOW PREV. CLOSE       LTP  \
# 0  01-Jan-26     EQ  3,215.00  3,234.10  3,198.20    3,206.20  3,225.00
# 1  31-Dec-25     EQ  3,240.00  3,246.00  3,198.50    3,246.80  3,210.00
# 2  30-Dec-25     EQ  3,250.00  3,267.50  3,239.50    3,251.50  3,255.00
# 3  29-Dec-25     EQ  3,280.00  3,288.00  3,242.90    3,280.00  3,256.00
# 4  26-Dec-25     EQ  3,313.10  3,320.00  3,271.80    3,319.00  3,276.80
#
#       CLOSE      VWAP     52W H     52W L   VOLUME               VALUE  \
# 0  3,227.40  3,219.97  4,322.95  2,866.60  1255735   4,04,34,25,200.10
# 1  3,206.20  3,216.08  4,322.95  2,866.60  3362634  10,81,45,02,991.90
# 2  3,246.80  3,250.64  4,322.95  2,866.60  2807593   9,12,64,73,823.50
# 3  3,251.50  3,254.98  4,322.95  2,866.60  2079473   6,76,86,50,796.40
# 4  3,280.00  3,287.91  4,322.95  2,866.60  1176664   3,86,87,59,940.60
#
#    NO. OF  TRADES
# 0           56642
# 1          145683
# 2          184541
# 3          117390
# 4           89363
#
# 🔹 LAST 5 ROWS
#            DATE SERIES      OPEN      HIGH       LOW PREV. CLOSE       LTP  \
# 1488  07-Jan-20     EQ  2,200.50  2,214.65  2,183.80    2,200.45  2,205.00
# 1489  06-Jan-20     EQ  2,205.00  2,225.95  2,187.90    2,200.65  2,201.35
# 1490  03-Jan-20     EQ  2,164.00  2,223.00  2,164.00    2,157.65  2,201.00
# 1491  02-Jan-20     EQ  2,179.95  2,179.95  2,149.20    2,167.60  2,157.00
# 1492  01-Jan-20     EQ  2,168.00  2,183.90  2,154.00    2,161.70  2,170.00
#
#          CLOSE      VWAP     52W H     52W L   VOLUME               VALUE  \
# 1488  2,205.85  2,203.53  2,296.20  1,808.00  2429317   5,35,30,63,591.10
# 1489  2,200.45  2,204.89  2,296.20  1,808.00  3023209   6,66,58,55,309.10
# 1490  2,200.65  2,199.26  2,296.20  1,808.00  4655761  10,23,92,06,390.20
# 1491  2,157.65  2,158.63  2,296.20  1,808.00  2380752   5,13,91,56,143.05
# 1492  2,167.60  2,170.54  2,296.20  1,808.00  1354908   2,94,08,82,381.95
#
#       NO. OF  TRADES
# 1488           95018
# 1489          135360
# 1490          123516
# 1491           99242
# 1492           44438

# %%
print("\n🔹 SHAPE OF DATASET")
print("Rows:", data.shape[0])
print("Columns:", data.shape[1])

print("\n🔹 COLUMN NAMES")
print(data.columns)

print("\n🔹 DATA TYPES")
print(data.dtypes)
# Out:
# 🔹 SHAPE OF DATASET
# Rows: 1493
# Columns: 14
#
# 🔹 COLUMN NAMES
# Index(['DATE', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'PREV. CLOSE', 'LTP', 'CLOSE',
#        'VWAP', '52W H', '52W L', 'VOLUME', 'VALUE', 'NO. OF  TRADES'],
#       dtype='object')
#
# 🔹 DATA TYPES
# DATE              object
# SERIES            object
# OPEN              object
# HIGH              object
# LOW               object
# PREV. CLOSE       object
# LTP               object
# CLOSE             object
# VWAP              object
# 52W H             object
# 52W L             object
# VOLUME             int64
# VALUE             object
# NO. OF  TRADES     int64
# dtype: object

# %%
print("\n🔹 DATASET INFO")
data.info()
# Out:
# 🔹 DATASET INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1493 entries, 0 to 1492
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            1493 non-null   object
#  1   SERIES          1493 non-null   object
#  2   OPEN            1493 non-null   object
#  3   HIGH            1493 non-null   object
#  4   LOW             1493 non-null   object
#  5   PREV. CLOSE     1493 non-null   object
#  6   LTP             1493 non-null   object
#  7   CLOSE           1493 non-null   object
#  8   VWAP            1493 non-null   object
#  9   52W H           1493 non-null   object
#  10  52W L           1493 non-null   object
#  11  VOLUME          1493 non-null   int64
#  12  VALUE           1493 non-null   object
#  13  NO. OF  TRADES  1493 non-null   int64
# dtypes: int64(2), object(12)
# memory usage: 163.4+ KB

# %%
print("\n🔹 NULL VALUES")
print(data.isnull().sum())
# Out:
# 🔹 NULL VALUES
# DATE              0
# SERIES            0
# OPEN              0
# HIGH              0
# LOW               0
# PREV. CLOSE       0
# LTP               0
# CLOSE             0
# VWAP              0
# 52W H             0
# 52W L             0
# VOLUME            0
# VALUE             0
# NO. OF  TRADES    0
# dtype: int64

# %%
print("\n🔹 NULL VALUE PERCENTAGE")
print((data.isnull().sum() / len(data)) * 100)
# Out:
# 🔹 NULL VALUE PERCENTAGE
# DATE              0.0
# SERIES            0.0
# OPEN              0.0
# HIGH              0.0
# LOW               0.0
# PREV. CLOSE       0.0
# LTP               0.0
# CLOSE             0.0
# VWAP              0.0
# 52W H             0.0
# 52W L             0.0
# VOLUME            0.0
# VALUE             0.0
# NO. OF  TRADES    0.0
# dtype: float64
